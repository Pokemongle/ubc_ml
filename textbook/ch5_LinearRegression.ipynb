# %% [markdown]
# # 5.2 Least Squares Linear Regression
# fitting a hyperplane to a scatter of P points in (N+1)-dim space
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115171442.png)
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115171516.png) ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115171504.png)
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115171531.png)
# - Notation
#     - Input:
#     ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115145100.png)
#     ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115145145.png)
# - Least Square Cost Function
#     ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115172406.png)
#     ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115175329.png)
#     - normal equation
#     ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115175743.png)

# %% [markdown]
# # 5.3 Least Absolute Deviations

# %% [markdown]
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115180941.png)

# %% [markdown]
# # 5.4 Regression Quality Metrics
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115181921.png)
# ![image.png](https://raw.githubusercontent.com/Pokemongle/img_bed_0/main/img/20251115181935.png)

# %% [markdown]
# # 5.5 Weighted Regression

# %% [markdown]
# # 5.6 Multi-Output Regression
